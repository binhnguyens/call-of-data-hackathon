# %% [markdown]
# # Call of Data - Datathon
# ##### First place winners of 2019 event hosted by Acorn Talents
#
# ## Objective and Goals
# Our goal of this project was to create an interactive demo to locate various washrooms throughout Toronto
#
# The dataset used was given by Toronto Parks and Recreation Washroom Facilities
#
# The dataset contained information such as the ID, Building Name, Coordinates (Lattitude and Longitude)
#
# Psuedo data was created to give ratings and comments alongside the location of the washroom
#
# # Credits
# Author of this code was created by Binh Nguyen and Vlad Dubrovsky
#
# Additional credit given to: https://medium.com/analytics-vidhya/introduction-to-interactive-geoplots-with-plotly-and-mapbox-9249889358eb

# %% [markdown]
# # Import neccessary libraries
# These are various libraries that were used to create this product

# %%
#import necessary libraries
import numpy as np 
import pandas as pd
import plotly 
import plotly.plotly as py
import plotly.offline as offline
import plotly.graph_objs as go
from plotly.offline import iplot
from geopy.distance import geodesic
offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # Read data that was pre-processed in another program
# Another program was used to pre-process that data, by seperating the coordinates into longitude and latitdue, and the access information (which was not used).
#
# Alongside the preprocessing, the pseudo ratings were randomly created and applied alongside each entry.
#
# The building names were shorten to a "Clean Name" because there was difficulty displaying the full length names of each building
#
# The following dataset was the result of the pre-process:
#
# 1. Latitude
# 2. Longitude
# 3. Access (which was not used)
# 4. Building Name
# 5. Shorten Building Names
# 6. Ratings
# 7. Clean Ratings/Comments

# %%
#train = pd.read_csv ('train.csv', nrows = 50)

train = pd.read_csv ('lat_lon.csv')
print (train)
# Out:
#       latitude  longitude   access  \
# 0    43.792179 -79.146869   Public
# 1    43.792990 -79.145822  Private
# 2    43.729641 -79.294532   Public
# 3    43.662231 -79.462541   Public
# 4    43.670326 -79.284723   Public
# 5    43.670398 -79.287120   Public
# 6    43.784471 -79.360939   Public
# 7    43.694642 -79.370046  Members
# 8    43.660364 -79.418041   Public
# 9    43.682279 -79.281133  Private
# 10   43.713031 -79.227433   Public
# 11   43.706190 -79.234937   Public
# 12   43.745869 -79.352315   Public
# 13   43.783294 -79.315711   Public
# 14   43.637030 -79.449291   Public
# 15   43.713990 -79.466625   Public
# 16   43.662986 -79.448427   Public
# 17   43.636881 -79.344306   Public
# 18   43.665179 -79.422391   Public
# 19   43.746071 -79.437754   Public
# 20   43.609754 -79.529714  Members
# 21   43.634343 -79.404742   Public
# 22   43.726573 -79.260199  Private
# 23   43.686763 -79.387574   Public
# 24   43.758136 -79.505463   Public
# 25   43.691891 -79.334714   Public
# 26   43.745750 -79.412065   Public
# 27   43.750337 -79.423235   Public
# 28   43.657023 -79.433584   Public
# 29   43.657053 -79.432196   Public
# ..         ...        ...      ...
# 131  43.620279 -79.376307   Public
# 132  43.622313 -79.379074   Public
# 133  43.613801 -79.381613    Staff
# 134  43.623565 -79.381752  Private
# 135  43.620367 -79.373115   Public
# 136  43.624404 -79.383599  Private
# 137  43.623296 -79.373683   Public
# 138  43.631066 -79.357068   Public
# 139  43.620741 -79.365291   Public
# 140  43.628854 -79.355553   Public
# 141  43.631260 -79.353808   Public
# 142  43.776590 -79.506974   Public
# 143  43.751051 -79.400595  Members
# 144  43.649535 -79.413687   Public
# 145  43.649063 -79.415094   Public
# 146  43.728825 -79.391878   Public
# 147  43.644553 -79.547550   Public
# 148  43.657114 -79.573793  Members
# 149  43.682337 -79.416343   Public
# 150  43.660838 -79.557552  Members
# 151  43.733672 -79.297183   Public
# 152  43.721438 -79.352997   Public
# 153  43.769839 -79.316965   Public
# 154  43.674704 -79.346394   Public
# 155  43.675868 -79.348005   Public
# 156  43.675675 -79.347430   Public
# 157  43.672893 -79.345616   Public
# 158  43.664965 -79.304712   Public
# 159  43.662746 -79.307918   Public
# 160  43.664861 -79.312223   Public
#
#                                          Building Name  Unnamed: 4  \
# 0                    ADAMS PARK MAINTENANCE FIELDHOUSE         NaN
# 1                       ADAMS PARK BASEBALL FIELDHOUSE         NaN
# 2         ASHTONBEE RESERVOIR PARK - Washroom Building         NaN
# 3                       WEST TORONTO LAWN BOWLING CLUB         NaN
# 4                               SILVERBIRCH BOAT HOUSE         NaN
# 5                   BALMY BEACH LAWN BOWLING CLUBHOUSE         NaN
# 6                            BELLBURY PARK TENNIS CLUB         NaN
# 7                    BENNINGTON HEIGHTS PARK CLUBHOUSE         NaN
# 8                    BICKFORD PARK - Washroom Building         NaN
# 9                             BLANTYRE PARK FIELDHOUSE         NaN
# 10                        BLUFFER'S PARK EAST WASHROOM         NaN
# 11                        BLUFFER'S PARK WEST WASHROOM         NaN
# 12                              BOND PARK SPORT CENTRE         NaN
# 13                        BRIDLEWOOD PARK - Fieldhouse         NaN
# 14                          BUDAPEST PARK - Fieldhouse         NaN
# 15                         CALEDONIA PARK - Fieldhouse         NaN
# 16          CAMPBELL AVENUE PLAYGROUND A.I.R. BUILDING         NaN
# 17   CHERRY BEACH CLARKE BEACH PARK - Washroom Buil...         NaN
# 18                  CHRISTIE PITS PARK A.I.R. BUILDING         NaN
# 19                       CLANTON PARK TENNIS CLUBHOUSE         NaN
# 20                        CONNORVALE PARK - Fieldhouse         NaN
# 21                                CORONATION PARK YARD         NaN
# 22                   CORVETTE PARK - Washroom Building         NaN
# 23            DAVID A. BALFOUR PARK - Storage Building         NaN
# 24                 DERRYDOWNS PARK - Washroom Building         NaN
# 25                     DIEPPE PARK - Washroom Building         NaN
# 26           DON VALLEY GOLF COURSE BACK NINE WASHROOM         NaN
# 27          DON VALLEY GOLF COURSE FRONT NINE WASHROOM         NaN
# 28                    DUFFERIN GROVE PARK - Fieldhouse         NaN
# 29              DUFFERIN GROVE PARK - Storage Building         NaN
# ..                                                 ...         ...
# 131                 ISLAND PARK WASHROOM - BUILDING 35         NaN
# 132     ISLAND PARK WASHROOM AND SHELTER - BUILDING 38         NaN
# 133              ISLAND PARK WHITE HOUSE - BUILDING 26         NaN
# 134    ISLAND PARK MARINA WASHROOM (  1) - BUILDING 33         NaN
# 135     ISLAND PARK CENTREVILLE WASHROOM - BUILDING 34         NaN
# 136                  ISLAND PARK MARINA WASHROOM (  2)         NaN
# 137        OLYMPIC ISLAND PARK WASHROOMS - BUILDING 47         NaN
# 138             WARD'S ISLAND FERRY DOCK WAITING HOUSE         NaN
# 139       WARD'S ISLAND "CHIPPEWA HOUSE" - BUILDING 68         NaN
# 140  WARD'S ISLAND PARK SUNSHINE CENTRE FOR SENIORS...         NaN
# 141          WARD'S ISLAND PARK WASHROOM - BUILDING 60         NaN
# 142                     TORONTO TRACK AND FIELD CENTRE         NaN
# 143                   TOURNAMENT PARK TENNIS CLUBHOUSE         NaN
# 144   TRINITY BELLWOODS PARK - Washroom Building (  2)         NaN
# 145   TRINITY BELLWOODS PARK - Washroom Building (  1)         NaN
# 146                          WANLESS PARK - Fieldhouse         NaN
# 147                     WEDGEWOOD PARK A.I.R. BUILDING         NaN
# 148               WELLESWORTH PARK - Washroom Building         NaN
# 149                WELLS HILL PARK - Washroom Building         NaN
# 150                WEST DEANE PARK - Washroom Building         NaN
# 151                          WEXFORD PARK - Fieldhouse         NaN
# 152  WILKET CREEK PARK WASHROOM AND MAINTENANCE BUI...         NaN
# 153                     WISHING WELL PARK - Fieldhouse         NaN
# 154                   WITHROW PARK - Washroom Building         NaN
# 155                             WITHROW PARK CLUBHOUSE         NaN
# 156               WITHROW PARK NORTH WASHROOM BUILDING         NaN
# 157               WITHROW PARK SOUTH WASHROOM BUILDING         NaN
# 158                DONALD D. SUMMERVILLE OLYMPIC POOLS         NaN
# 159                           WOODBINE BATHING STATION         NaN
# 160                         WOODBINE PARK - Fieldhouse         NaN
#
#      Unnamed: 5  clean names      ratings   clean ratings
# 0           NaN        ADAMS  Rating: 1/5           Dirty
# 1           NaN        ADAMS  Rating: 3/5           Dirty
# 2           NaN    ASHTONBEE  Rating: 5/5           Dirty
# 3           NaN         WEST  Rating: 1/5  Mediocre Clean
# 4           NaN  SILVERBIRCH  Rating: 4/5           Clean
# 5           NaN        BALMY  Rating: 0/5           Clean
# 6           NaN     BELLBURY  Rating: 0/5           Dirty
# 7           NaN   BENNINGTON  Rating: 4/5           Clean
# 8           NaN     BICKFORD  Rating: 1/5  Mediocre Clean
# 9           NaN     BLANTYRE  Rating: 4/5           Clean
# 10          NaN    BLUFFER'S  Rating: 4/5           Dirty
# 11          NaN    BLUFFER'S  Rating: 3/5  Mediocre Clean
# 12          NaN         BOND  Rating: 2/5           Clean
# 13          NaN   BRIDLEWOOD    No Rating           Clean
# 14          NaN     BUDAPEST    No Rating           Clean
# 15          NaN    CALEDONIA  Rating: 4/5           Clean
# 16          NaN     CAMPBELL  Rating: 5/5  Mediocre Clean
# 17          NaN       CHERRY  Rating: 0/5           Clean
# 18          NaN     CHRISTIE  Rating: 0/5  Mediocre Clean
# 19          NaN      CLANTON  Rating: 4/5           Dirty
# 20          NaN   CONNORVALE  Rating: 0/5           Dirty
# 21          NaN   CORONATION    No Rating  Mediocre Clean
# 22          NaN     CORVETTE  Rating: 1/5           Dirty
# 23          NaN        DAVID  Rating: 1/5  Mediocre Clean
# 24          NaN   DERRYDOWNS  Rating: 4/5           Dirty
# 25          NaN       DIEPPE  Rating: 3/5           Clean
# 26          NaN          DON  Rating: 0/5           Dirty
# 27          NaN          DON    No Rating  Mediocre Clean
# 28          NaN     DUFFERIN  Rating: 5/5           Clean
# 29          NaN     DUFFERIN    No Rating  Mediocre Clean
# ..          ...          ...          ...             ...
# 131         NaN       ISLAND  Rating: 2/5  Mediocre Clean
# 132         NaN       ISLAND    No Rating           Clean
# 133         NaN       ISLAND  Rating: 0/5           Dirty
# 134         NaN       ISLAND    No Rating  Mediocre Clean
# 135         NaN       ISLAND  Rating: 5/5           Clean
# 136         NaN       ISLAND  Rating: 4/5           Dirty
# 137         NaN      OLYMPIC  Rating: 1/5           Dirty
# 138         NaN       WARD'S    No Rating  Mediocre Clean
# 139         NaN       WARD'S  Rating: 2/5           Clean
# 140         NaN       WARD'S    No Rating           Clean
# 141         NaN       WARD'S  Rating: 0/5           Clean
# 142         NaN      TORONTO  Rating: 0/5           Clean
# 143         NaN   TOURNAMENT  Rating: 0/5           Clean
# 144         NaN      TRINITY  Rating: 1/5           Clean
# 145         NaN      TRINITY  Rating: 4/5           Clean
# 146         NaN      WANLESS  Rating: 1/5           Clean
# 147         NaN    WEDGEWOOD  Rating: 5/5           Clean
# 148         NaN  WELLESWORTH    No Rating  Mediocre Clean
# 149         NaN        WELLS  Rating: 3/5  Mediocre Clean
# 150         NaN         WEST  Rating: 0/5           Clean
# 151         NaN      WEXFORD  Rating: 4/5  Mediocre Clean
# 152         NaN       WILKET  Rating: 5/5           Clean
# 153         NaN      WISHING    No Rating  Mediocre Clean
# 154         NaN      WITHROW  Rating: 0/5           Dirty
# 155         NaN      WITHROW  Rating: 2/5           Dirty
# 156         NaN      WITHROW  Rating: 3/5  Mediocre Clean
# 157         NaN      WITHROW  Rating: 1/5  Mediocre Clean
# 158         NaN       DONALD  Rating: 3/5  Mediocre Clean
# 159         NaN     WOODBINE  Rating: 1/5  Mediocre Clean
# 160         NaN     WOODBINE  Rating: 1/5  Mediocre Clean
#
# [161 rows x 9 columns]

# %% [markdown]
# # Rating Function
# Created a rating function so when a user inputs a value, a proper format will be outputted

# %%
def rating_fct (rating_1):
    if (rating_1 ==0):
        return 'Rating = 0/5'
    if (rating_1 ==1):
        return 'Rating = 1/5'
    if (rating_1 ==2):
        return 'Rating = 2/5'
    if (rating_1 ==3):
        return 'Rating = 3/5'
    if (rating_1 ==4):
        return 'Rating = 4/5'
    if (rating_1 ==5):
        return 'Rating = 5/5'

# %% [markdown]
# # Get the location that is closest to you

# %%
def closest_loc (input):
    if input ==1:
        coordinates = (43.6417, -79.4123)
        # Pager Duty
        return coordinates
    elif input ==2:
        coordinates = (43.6629, -79.3957)
        # Uoft
        return coordinates
    elif input ==3:
        coordinates = (43.6577, -79.3788)
        # Ryerson 
        return coordinates

# %% [markdown]
# # Map out the closest washroom
# The following code is done to
#
# 1. Ask the user of their position. Currently only 3 positions have been inputed as options to simplify things
# 2. The Geo distance between the closest washroom and your position is calculated
#
# Following that, a set of code is called (line 26 to 56) to output the mapping
#
# The latitude and longitude of your location, and the closest washroom are placed in line 30 and 31. Various parameters were changed accordingly to output particular interests

# %%
list_names =  train ['clean names'] +' -- ' + train ['ratings'] + ' -- ' + train ['clean ratings']
#print list_names [1]

list_names1 = list_names
# print (list_names1)

location_input = input("What is your location? (Enter a number) \n 1. PagerDuty \n 2. St. George \n 3. Ryerson\n")
coordinates_input = closest_loc(location_input)

geo_distance = [''] * len(train['latitude'])
for i in range (len(train['latitude'])):
    washroom_coordinates  = (train['latitude'][i],train['longitude'][i])
    geo_distance [i]= (geodesic(coordinates_input, washroom_coordinates).miles)
#     print (geo_distance)

min_distance = (min(geo_distance))
iteration_distance = geo_distance.index (min_distance)

print '-------------------------------------------------------------'
print "Your Closest location is: ", list_names[iteration_distance]
print "It is ", min_distance, " KM far"



shaz13_custom_style = "mapbox://styles/mapbox/navigation-preview-night-v4"
#"mapbox://styles/shaz13/cjiog1iqa1vkd2soeu5eocy4i"
#set the geo=spatial data
data = [go.Scattermapbox(
            lat= [coordinates_input[0], train['latitude'][iteration_distance]],
            lon= [coordinates_input[1],train['longitude'][iteration_distance]],
            #access = train ['access']
            #customdata = train['key'],
            mode='markers',
            marker=go.scattermapbox.Marker(
            size=14),
            text= ['Your location', list_names[iteration_distance]],
            hoverinfo='text'
        )
        ]
#set the layout to plot
layout = go.Layout(autosize=True,
                   hovermode = 'closest',                   
                   mapbox= go.layout.Mapbox(accesstoken="pk.eyJ1IjoiZmFwcHliaXJkIiwiYSI6ImNqdDFucXRsbTBnc3AzeXM3MGxoNThjZWoifQ.Vt1pyS9wffni8aSdJ9hTcA",
                                bearing=0,
                                pitch=0,
                                zoom=13,
                                center= go.layout.mapbox.Center(lat= train['latitude'][iteration_distance],
                                             lon=train['longitude'][iteration_distance]),
                                style=shaz13_custom_style),
                    width=900,
                    height=600, 
                    title = "Toronto Washroom Closest to your Location")

fig = dict(data=data, layout=layout)
iplot(fig)
# Out:
# What is your location? (Enter a number)
#  1. PagerDuty
#  2. St. George
#  3. Ryerson
# 1
# -------------------------------------------------------------
# Your Closest location is:  STANLEY -- No Rating -- Clean
# It is  0.166988556016  KM far
# <div id="3e35c76f-0763-4665-ad92-db34d64f0929" style="height: 600px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("3e35c76f-0763-4665-ad92-db34d64f0929")) {
#     Plotly.newPlot("3e35c76f-0763-4665-ad92-db34d64f0929", [{"uid": "106e9833-684d-4562-ba59-4fbea3942da3", "text": ["Your location", "STANLEY -- No Rating -- Clean"], "lon": [-79.4123, -79.409312], "lat": [43.6417, 43.64276864], "mode": "markers", "hoverinfo": "text", "marker": {"size": 14}, "type": "scattermapbox"}], {"autosize": true, "title": {"text": "Toronto Washroom Closest to your Location"}, "height": 600, "width": 900, "mapbox": {"bearing": 0, "style": "mapbox://styles/mapbox/navigation-preview-night-v4", "center": {"lat": 43.64276864, "lon": -79.409312}, "accesstoken": "pk.eyJ1IjoiZmFwcHliaXJkIiwiYSI6ImNqdDFucXRsbTBnc3AzeXM3MGxoNThjZWoifQ.Vt1pyS9wffni8aSdJ9hTcA", "zoom": 13, "pitch": 0}, "hovermode": "closest"}, {"plotlyServerURL": "https://plot.ly", "linkText": "Export to plot.ly", "showLink": false});
# }
# });</script>

# %% [markdown]
# # Get the rating of the location of the washroom
# ## Input rating to location of washroom and Be able to see ratings nearby
#
# For demonstration purposes, STANLEY was the washroom we decided to add a rating and a comment. This was done because STANLEY was the closest washroom to Pager Duty (the location of the hackathon)

# %%
list_names =  train ['clean names'] +' -- ' + train ['ratings'] + ' -- ' + train ['clean ratings']
#print list_names [1]

list_names1 = list_names
# print (list_names1)

location_input = raw_input("What is your location? (ENTER STANLEY)")
clean_input = raw_input("Add your comment? ")
rating_input = input("What is your Rating of the location? (OUT OF 5)")



for i in range (len(list_names)):
    x,y,z = list_names[i].split (' -- ')
    y = rating_fct (rating_input)
    z = clean_input
    if x == location_input:
        list_names1[i] = x+' -- ' + y +' -- ' + z
        print list_names1[i]
        
            

shaz13_custom_style = "mapbox://styles/mapbox/navigation-preview-night-v4"
#"mapbox://styles/shaz13/cjiog1iqa1vkd2soeu5eocy4i"
#set the geo=spatial data
data = [go.Scattermapbox(
            lat= train['latitude'],
            lon= train['longitude'],
            #access = train ['access']
            #customdata = train['key'],
            mode='markers',
            marker=go.scattermapbox.Marker(
            size=14),
            text= list_names1,
            #hoverinfo='text',

        )
        ]
#set the layout to plot
layout = go.Layout(autosize=True,
                   hovermode = 'closest',                   
                   mapbox= go.layout.Mapbox(accesstoken="pk.eyJ1IjoiZmFwcHliaXJkIiwiYSI6ImNqdDFucXRsbTBnc3AzeXM3MGxoNThjZWoifQ.Vt1pyS9wffni8aSdJ9hTcA",
                                bearing=0,
                                pitch=0,
                                zoom=13,
                                center= go.layout.mapbox.Center(lat=43.64276864,
                                             lon=-79.409312),
                                style=shaz13_custom_style),
                    width=900,
                    height=600, 
                    title = "Toronto Locations with Washrooms with Ratings")

fig = dict(data=data, layout=layout)
iplot(fig)
# Out:
# What is your location? (ENTER STANLEY)STANLEY
# Add your comment? alright
# What is your Rating of the location? (OUT OF 5)2
# STANLEY -- Rating = 2/5 -- alright
# <div id="b3ebede9-2f97-4952-94d9-8ebd2d106262" style="height: 600px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("b3ebede9-2f97-4952-94d9-8ebd2d106262")) {
#     Plotly.newPlot("b3ebede9-2f97-4952-94d9-8ebd2d106262", [{"uid": "77b1f8cb-6e47-4cd7-800d-82465ddd2b3d", "text": ["ADAMS -- Rating: 1/5 -- Dirty", "ADAMS -- Rating: 3/5 -- Dirty", "ASHTONBEE -- Rating: 5/5 -- Dirty", "WEST -- Rating: 1/5 -- Mediocre Clean", "SILVERBIRCH -- Rating: 4/5 -- Clean", "BALMY -- Rating: 0/5 -- Clean", "BELLBURY -- Rating: 0/5 -- Dirty", "BENNINGTON -- Rating: 4/5 -- Clean", "BICKFORD -- Rating: 1/5 -- Mediocre Clean", "BLANTYRE -- Rating: 4/5 -- Clean", "BLUFFER'S -- Rating: 4/5 -- Dirty", "BLUFFER'S -- Rating: 3/5 -- Mediocre Clean", "BOND -- Rating: 2/5 -- Clean", "BRIDLEWOOD -- No Rating -- Clean", "BUDAPEST -- No Rating -- Clean", "CALEDONIA -- Rating: 4/5 -- Clean", "CAMPBELL -- Rating: 5/5 -- Mediocre Clean", "CHERRY -- Rating: 0/5 -- Clean", "CHRISTIE -- Rating: 0/5 -- Mediocre Clean", "CLANTON -- Rating: 4/5 -- Dirty", "CONNORVALE -- Rating: 0/5 -- Dirty", "CORONATION -- No Rating -- Mediocre Clean", "CORVETTE -- Rating: 1/5 -- Dirty", "DAVID -- Rating: 1/5 -- Mediocre Clean", "DERRYDOWNS -- Rating: 4/5 -- Dirty", "DIEPPE -- Rating: 3/5 -- Clean", "DON -- Rating: 0/5 -- Dirty", "DON -- No Rating -- Mediocre Clean", "DUFFERIN -- Rating: 5/5 -- Clean", "DUFFERIN -- No Rating -- Mediocre Clean", "DUNLOP -- Rating: 3/5 -- Dirty", "EARL -- Rating: 1/5 -- Mediocre Clean", "EARL -- Rating: 3/5 -- Dirty", "EARLSCOURT -- Rating: 3/5 -- Mediocre Clean", "EARLSCOURT -- Rating: 2/5 -- Mediocre Clean", "EDWARDS -- Rating: 5/5 -- Clean", "EDWARDS -- Rating: 5/5 -- Dirty", "EGLINTON -- Rating: 4/5 -- Dirty", "EGLINTON -- Rating: 0/5 -- Mediocre Clean", "ERINGATE -- Rating: 3/5 -- Clean", "ESTHER -- No Rating -- Clean", "ETIENNE -- Rating: 3/5 -- Dirty", "ETOBICOKE -- Rating: 3/5 -- Mediocre Clean", "FELSTEAD -- Rating: 2/5 -- Clean", "FRED -- Rating: 4/5 -- Dirty", "G. -- Rating: 1/5 -- Clean", "GEORGE -- No Rating -- Mediocre Clean", "GLAMORGAN -- Rating: 4/5 -- Clean", "GREENWOOD -- Rating: 0/5 -- Dirty", "GWENDOLEN -- Rating: 5/5 -- Clean", "HARBOUR -- Rating: 4/5 -- Mediocre Clean", "HENDON -- Rating: 0/5 -- Dirty", "HIGH -- Rating: 1/5 -- Mediocre Clean", "HIGH -- Rating: 3/5 -- Dirty", "HIGH -- No Rating -- Dirty", "HIGH -- Rating: 4/5 -- Clean", "HIGH -- No Rating -- Clean", "HIGH -- Rating: 3/5 -- Clean", "HIGH -- Rating: 1/5 -- Dirty", "HIGHVIEW -- No Rating -- Mediocre Clean", "HILLCREST -- Rating: 5/5 -- Dirty", "HINDER -- No Rating -- Dirty", "HOME -- Rating: 3/5 -- Mediocre Clean", "HOWARD -- Rating: 4/5 -- Mediocre Clean", "IROQUOIS -- Rating: 3/5 -- Mediocre Clean", "JAMES -- Rating: 4/5 -- Dirty", "JEAN -- Rating: 3/5 -- Clean", "DAVISVILLE -- Rating: 0/5 -- Dirty", "KEELESDALE -- Rating: 0/5 -- Dirty", "KEW -- Rating: 5/5 -- Clean", "KEW -- Rating: 5/5 -- Mediocre Clean", "L'AMOREAUX -- Rating: 1/5 -- Dirty", "KIDSTOWN -- Rating: 5/5 -- Mediocre Clean", "LAWRENCE -- Rating: 0/5 -- Dirty", "LESLIE -- Rating: 0/5 -- Dirty", "LITHUANIA -- Rating: 3/5 -- Mediocre Clean", "LITTLE -- Rating: 1/5 -- Clean", "LYTTON -- Rating: 3/5 -- Dirty", "LYTTON -- Rating: 0/5 -- Dirty", "MACGREGOR -- No Rating -- Clean", "MARIE -- Rating: 2/5 -- Mediocre Clean", "MARIE -- Rating: 4/5 -- Clean", "MCCLEARY -- Rating: 0/5 -- Dirty", "MILLIKEN -- No Rating -- Dirty", "MILLWOOD -- Rating: 0/5 -- Mediocre Clean", "MORSE -- Rating: 4/5 -- Mediocre Clean", "NATHAN -- Rating: 3/5 -- Dirty", "NEILSON -- No Rating -- Clean", "NORTHWOOD -- No Rating -- Clean", "NORWOOD -- Rating: 2/5 -- Clean", "ORIOLE -- Rating: 4/5 -- Mediocre Clean", "PANTRY -- Rating: 2/5 -- Clean", "PERTH -- Rating: 5/5 -- Clean", "PORT -- Rating: 1/5 -- Mediocre Clean", "PRAIRIE -- Rating: 0/5 -- Clean", "QUEENSWAY -- Rating: 3/5 -- Mediocre Clean", "RAMSDEN -- Rating: 5/5 -- Clean", "RAMSDEN -- No Rating -- Clean", "RIVERDALE -- Rating: 2/5 -- Mediocre Clean", "RIVERDALE -- Rating: 5/5 -- Dirty", "RIVERDALE -- Rating: 4/5 -- Clean", "ROSEDALE -- Rating: 5/5 -- Clean", "ROSETTA -- Rating: 2/5 -- Dirty", "ROWNTREE -- Rating: 3/5 -- Mediocre Clean" ...
